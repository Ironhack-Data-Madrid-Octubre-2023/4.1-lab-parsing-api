# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
import json
import requests as req
import pandas as pd

# %% [markdown]
# ### Promo Homme

# %%
url = f'https://www.zalando.fr/promo-homme/'

# %%
res = req.get(url)
res
# Out:
# <Response [200]>

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
res_api = res.text
lista_html = res_api.split('\n')

clean = []

for i in lista_html:
    if '<div><script>document.body' in i:
        clean.append(i)
        break
        
clean[0]
# Out:
# '<div><script>document.body && document.body.appendChild(document.createElement("script"));</script><div data-re><x-wrapper-pre-shell style="display:block"><script data-re-asset>require(["https://mosaic02.ztat.net/rnd/ng/app-download-banner/index-2667ffb6b12a68a4d1d5.js"])</script><x-wrapper-re-1-5 re-hydration-id="re-1-5" style="display:block"></x-wrapper-re-1-5><script type="application/json" class="re-data-el-init">{"enrichedRootEntity":{"id":"ern:collection:cat:categ:promo-homme","type":"collection","hints":["catalog"],"rawExternalData":"%257B%2522filters%2522:%257B%2522discreteFilters%2522:null%252C%2522rangeFilters%2522:null%252C%2522toggleFilters%2522:null%257D%257D"},"locale":"fr-FR","additionalModules":[],"rendererCache":[{"name":"null","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/null/index-a277baa15503b3948459.js"},"queriesMeta":[]},{"name":"brand_card","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/brand_card/index-0ee8655e0343691fb431.js"},"queriesMeta":[{"subscriptionsPaths":[["brand"]]}]},{"name":"brand_home-view","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/brand_home-view/index-d0bde6c7a5ce7be0cb30.js"},"queriesMeta":[{"subscriptionsPaths":[["brand"]]}]},{"name":"brand_bio-banner","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/brand_bio-banner/index-a75d0511c872279b246c.js"},"queriesMeta":[]},{"name":"brand_bio-highlight","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/brand_bio-highlight/index-242cfbb0ba917aa807a4.js"},"queriesMeta":[]},{"name":"collection_all-brands-view","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/collection_all-brands-view/index-ba89576a38e167d7dfdf.js"},"queriesMeta":[]},{"name":"campaign_collection-card","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/campaign_collection-card/index-7c88cd976e38862f49d7.js"},"queriesMeta":[]},{"name":"customer_campaigns_campaign","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/customer_campaigns_campaign/index-bc34d7d39c76bf9734bb.js"},"queriesMeta":[]},{"name":"collection_release-card","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/collection_release-card/index-b9dfdde2852e4f79969c.js"},"queriesMeta":[]},{"name":"short_player","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/short_player/index-32a5e086ce9bdcd1c390.js"},"queriesMeta":[]},{"name":"collection_shorts-dialog","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/collection_shorts-dialog/index-3c191390af2816bde98c.js"},"queriesMeta":[]},{"name":"collection_shorts-welcome-mat","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/collection_shorts-welcome-mat/index-bcc1df1b7e53b742eb85.js"},"queriesMeta":[]},{"name":"collection_shorts-grid","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/collection_shorts-grid/index-aa70461a9cf5f1a1181d.js"},"queriesMeta":[]},{"name":"collection_statement-carousel","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/collection_statement-carousel/index-a219238a2c5a0e64e7fa.js"},"queriesMeta":[]},{"name":"collection_statement-grid-entry-point","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/collection_statement-grid-entry-point/index-3ce028acb60578e7343a.js"},"queriesMeta":[]},{"name":"collection_statement-cards-entry-point","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/collection_statement-cards-entry-point/index-9d32e8bc7437585ba0fd.js"},"queriesMeta":[]},{"name":"short_card","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/short_card/index-998813b370991a952617.js"},"queriesMeta":[]},{"name":"collection_dropdown-filters","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/collection_dropdown-filters/index-7b0320eb36a65a50f12c.js"},"queriesMeta":[]},{"name":"collection_catalog-view","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/collection_catalog-view/index-90533c3d953a7d22323b.js"},"queriesMeta":[]},{"name":"collection_catalog-no-hits","assets":{"jsPath":"https://mosaic02.ztat.net/rnd/ng/collection_catalog-no-hits/index-182c03e95ba474e5ebb0.js"},"queriesMeta":[]},{"name":" ...

# %%
# This data can't be easily readed

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
